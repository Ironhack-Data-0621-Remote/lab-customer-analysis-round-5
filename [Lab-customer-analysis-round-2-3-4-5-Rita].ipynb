# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# # Customer analysis round 2

# %%
data = pd.read_csv('/Users/ritasilva/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
#1. Show dataframe shape

data.shape
# Out:
# (10910, 26)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
#2 Standardize header names.

# %%
data = data.drop('Unnamed: 0', axis = 1)   #delete columns Unnamed: 0 as it is identical to the index

# %%
data.columns = data.columns.str.lower().str.replace(' ','_')

# %%
data = data.rename(columns={'customer':'customer_id', 'employmentstatus':'employment_status'})

# %%
data
# Out:
#       customer_id       state  customer_lifetime_value response  coverage  \
# 0         DK49336     Arizona              4809.216960       No     Basic
# 1         KX64629  California              2228.525238       No     Basic
# 2         LZ68649  Washington             14947.917300       No     Basic
# 3         XL78013      Oregon             22332.439460      Yes  Extended
# 4         QA50777      Oregon              9025.067525       No   Premium
# ...           ...         ...                      ...      ...       ...
# 10905     FE99816      Nevada             15563.369440       No   Premium
# 10906     KX53892      Oregon              5259.444853       No     Basic
# 10907     TL39050     Arizona             23893.304100       No  Extended
# 10908     WA60547  California             11971.977650       No   Premium
# 10909     IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employment_status gender  income  ...  \
# ...

# %%
#3. Which columns are numerical?

data._get_numeric_data()
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
#4. Which columns are categorical?

data.select_dtypes('object')
# Out:
#       customer_id       state response  coverage education effective_to_date  \
# 0         DK49336     Arizona       No     Basic   College           2/18/11
# 1         KX64629  California       No     Basic   College           1/18/11
# 2         LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3         XL78013      Oregon      Yes  Extended   College           1/11/11
# 4         QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...           ...         ...      ...       ...       ...               ...
# 10905     FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906     KX53892      Oregon       No     Basic   College            1/6/11
# 10907     TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908     WA60547  California       No   Premium   College           2/13/11
# 10909     IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
# ...

# %%
data.isnull().sum()
# Out:
# customer_id                         0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employment_status                   0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# ...

# %%
#5. Check and deal with NaN values. QUESTION: By dropping NaN a lot of data is lost. What's the best solution to this?

data = data.dropna()
# Out:
#       customer_id       state  customer_lifetime_value response  coverage  \
# 2         LZ68649  Washington             14947.917300       No     Basic
# 3         XL78013      Oregon             22332.439460      Yes  Extended
# 10        HG93801     Arizona              5154.764074       No  Extended
# 13        KR82385  California              5454.587929       No     Basic
# 16        FH51383  California              5326.677654       No     Basic
# ...           ...         ...                      ...      ...       ...
# 10902     PP30874  California              3579.023825       No  Extended
# 10903     SU71163     Arizona              2771.663013       No     Basic
# 10904     QI63521      Nevada             19228.463620       No     Basic
# 10906     KX53892      Oregon              5259.444853       No     Basic
# 10908     WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employment_status gender  \
# ...

# %%
data.dtypes
# Out:
# customer_id                       object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employment_status                 object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %%
#6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

pd.to_datetime(data['effective_to_date'])
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: effective_to_date, Length: 10910, dtype: datetime64[ns]

# %%
data['effective_to_date'] = pd.to_datetime(data['effective_to_date'], errors='coerce')
data['effective_to_date']
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: effective_to_date, Length: 10910, dtype: datetime64[ns]

# %%
data.dtypes
# Out:
# customer_id                              object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employment_status                        object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
data.dtypes
# Out:
# customer_id                              object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employment_status                        object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
#Extract the months from the dataset and store in a separate column

data['effective_to_date_months'] = pd.DatetimeIndex(data['effective_to_date']).month

# %%
data
# Out:
#       customer_id       state  customer_lifetime_value response  coverage  \
# 2         LZ68649  Washington             14947.917300       No     Basic
# 3         XL78013      Oregon             22332.439460      Yes  Extended
# 10        HG93801     Arizona              5154.764074       No  Extended
# 13        KR82385  California              5454.587929       No     Basic
# 16        FH51383  California              5326.677654       No     Basic
# ...           ...         ...                      ...      ...       ...
# 10902     PP30874  California              3579.023825       No  Extended
# 10903     SU71163     Arizona              2771.663013       No     Basic
# 10904     QI63521      Nevada             19228.463620       No     Basic
# 10906     KX53892      Oregon              5259.444853       No     Basic
# 10908     WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employment_status gender  \
# ...

# %%
data[['effective_to_date', 'effective_to_date_months']]
# Out:
#       effective_to_date  effective_to_date_months
# 2            2011-02-10                         2
# 3            2011-01-11                         1
# 10           2011-01-02                         1
# 13           2011-01-26                         1
# 16           2011-02-07                         2
# ...                 ...                       ...
# 10902        2011-01-24                         1
# 10903        2011-01-07                         1
# 10904        2011-02-24                         2
# 10906        2011-01-06                         1
# 10908        2011-02-13                         2
#
# [4543 rows x 2 columns]

# %%
data['effective_to_date_months'].unique()
# Out:
# array([2, 1])

# %%
import calendar
data['effective_to_date_months'] = data['effective_to_date_months'].apply(lambda x: calendar.month_abbr[x])

# %%
data['effective_to_date_months']
# Out:
# 2        Feb
# 3        Jan
# 10       Jan
# 13       Jan
# 16       Feb
#         ...
# 10902    Jan
# 10903    Jan
# 10904    Feb
# 10906    Jan
# 10908    Feb
# Name: effective_to_date_months, Length: 4543, dtype: object

# %%
#filter the data to show only the information for the first quarter

q1 = data['effective_to_date_months'].isin(['Jan','Feb','Mar'])
data[q1]
# Out:
#       customer_id       state  customer_lifetime_value response  coverage  \
# 2         LZ68649  Washington             14947.917300       No     Basic
# 3         XL78013      Oregon             22332.439460      Yes  Extended
# 10        HG93801     Arizona              5154.764074       No  Extended
# 13        KR82385  California              5454.587929       No     Basic
# 16        FH51383  California              5326.677654       No     Basic
# ...           ...         ...                      ...      ...       ...
# 10902     PP30874  California              3579.023825       No  Extended
# 10903     SU71163     Arizona              2771.663013       No     Basic
# 10904     QI63521      Nevada             19228.463620       No     Basic
# 10906     KX53892      Oregon              5259.444853       No     Basic
# 10908     WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employment_status gender  \
# ...

# %%
y = lambda x: calendar.month_abbr[x]    #function to change Month number to Month abbrevation
y(1)
# Out:
# 'Jan'

# %% [markdown]
# # Customer Analysis Round 3

# %%
#1. Show DataFrame info

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4543 entries, 2 to 10908
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    4543 non-null   object
#  1   state                          4543 non-null   object
#  2   customer_lifetime_value        4543 non-null   float64
#  3   response                       4543 non-null   object
#  4   coverage                       4543 non-null   object
#  5   education                      4543 non-null   object
#  6   effective_to_date              4543 non-null   datetime64[ns]
#  7   employment_status              4543 non-null   object
#  8   gender                         4543 non-null   object
#  9   income                         4543 non-null   int64
#  10  location_code                  4543 non-null   object
#  11  marital_status                 4543 non-null   object
# ...

# %%
#2. Describe DataFrame

data.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              4543.000000   4543.000000           4543.000000
# mean               8033.714059  37453.033238             93.773278
# std                6959.529443  30257.399536             35.093661
# min                1904.000852      0.000000             61.000000
# 25%                4039.089902      0.000000             69.000000
# 50%                5846.520588  34455.000000             83.000000
# 75%                8936.596938  61560.000000            110.000000
# max               83325.381190  99961.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              4543.000000                    4543.000000
# mean                 15.111820                      48.153863
# std                  10.157925                      28.146904
# min                   0.000000                       0.000000
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#3. Show a plot of the total number of responses.

sns.countplot('response', data=data)     

plt.show()

# %%
#4. Show a plot of the response rate by the sales channel.

plt.figure(figsize=(20,8))
sns.countplot('sales_channel', hue='response', data=data)
plt.show()

# %%
#5. Show a plot of the response rate by the total claim amount

sns.boxplot(x='response', y='total_claim_amount', data=data)
plt.show()

# %%
#6 Show a plot of the response rate by income.

plt.figure(figsize=(6,6))

sns.barplot(x="response", y="income", data=data)
plt.show()

# %% [markdown]
# # Customer Analysis round 4

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#1. Check the data types of the columns. Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)

data.dtypes
# Out:
# customer_id                              object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employment_status                        object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
numerical = data.select_dtypes(include=np.number)

# %%
categoricals = data.select_dtypes(include=np.object)
categoricals
# Out:
#       customer_id       state response  coverage             education  \
# 2         LZ68649  Washington       No     Basic              Bachelor
# 3         XL78013      Oregon      Yes  Extended               College
# 10        HG93801     Arizona       No  Extended  High School or Below
# 13        KR82385  California       No     Basic                Master
# 16        FH51383  California       No     Basic  High School or Below
# ...           ...         ...      ...       ...                   ...
# 10902     PP30874  California       No  Extended  High School or Below
# 10903     SU71163     Arizona       No     Basic               College
# 10904     QI63521      Nevada       No     Basic  High School or Below
# 10906     KX53892      Oregon       No     Basic               College
# 10908     WA60547  California       No   Premium               College
#
#       employment_status gender location_code marital_status     policy_type  \
# ...

# %%
#Use seaborn library to construct distribution plots for the numerical variables

sns.distplot(data['customer_lifetime_value'], bins=40)
plt.show()
sns.distplot(data['income'], bins=40)
plt.show()
sns.distplot(data['monthly_premium_auto'], bins=40)
plt.show()
sns.distplot(data['months_since_last_claim'], bins=40)
plt.show()
sns.distplot(data['months_since_policy_inception'], bins=40)
plt.show()
sns.distplot(data['number_of_open_complaints'], bins=40)
plt.show()
sns.distplot(data['number_of_policies'], bins=40)
plt.show()
sns.distplot(data['total_claim_amount'], bins=40)
plt.show()

# %%
#Use Matplotlib to construct histograms

fig, axs = plt.subplots(2, 2)

axs[0, 0].hist(data['income'])
axs[0, 1].hist(data['customer_lifetime_value'])
axs[1, 0].hist(data['total_claim_amount'])
axs[1, 1].hist(data['monthly_premium_auto'])

plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#3. For the numerical variables, check the multicollinearity between the features. Please note that we will use the column total_claim_amount later as the target variable.

X = numerical.drop(['total_claim_amount'], axis=1)
y = numerical['total_claim_amount']

X = sm.add_constant(X)

model = sm.OLS(y,X).fit() 

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     total_claim_amount   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.522
# Method:                 Least Squares   F-statistic:                     708.3
# Date:                Thu, 10 Jun 2021   Prob (F-statistic):               0.00
# Time:                        11:45:07   Log-Likelihood:                -30604.
# No. Observations:                4543   AIC:                         6.122e+04
# Df Residuals:                    4535   BIC:                         6.128e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            76.0938     12.413      6.130      0.000      51.757     100.430
# ...

# %%
#4 Drop one of the two features that show a high correlation between them (greater than 0.9). Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features

X = numerical.drop(['total_claim_amount', 'number_of_open_complaints', 'months_since_last_claim', 'months_since_policy_inception', 'number_of_policies'], axis=1) 
y = numerical['total_claim_amount']

X = sm.add_constant(X)

model = sm.OLS(y,X).fit() 

print(model.summary())

#drop variables with p values > 0.05
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     total_claim_amount   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.521
# Method:                 Least Squares   F-statistic:                     1650.
# Date:                Thu, 10 Jun 2021   Prob (F-statistic):               0.00
# Time:                        12:21:41   Log-Likelihood:                -30607.
# No. Observations:                4543   AIC:                         6.122e+04
# Df Residuals:                    4539   BIC:                         6.125e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      69.4595      9.444      7.355      0.000      50.945      87.974
# ...

# %%
corr_data = numerical
correlations_matrix = corr_data.corr()  
correlations_matrix
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.015914
# income                                        0.015914  1.000000
# monthly_premium_auto                          0.413739 -0.007594
# months_since_last_claim                       0.029199 -0.010556
# months_since_policy_inception                 0.022465 -0.007987
# number_of_open_complaints                    -0.034924  0.001149
# number_of_policies                            0.015397 -0.013199
# total_claim_amount                            0.228579 -0.355311
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.413739                 0.029199
# income                                    -0.007594                -0.010556
# monthly_premium_auto                       1.000000                 0.000890
# ...

# %%
sns_plot = sns.heatmap(correlations_matrix, annot=True)
figure = sns_plot.get_figure()    
figure.savefig('svm_conf.png', dpi=400)
plt.show()

# %% [markdown]
# # Lab | Customer Analysis Round 5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4543 entries, 2 to 10908
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    4543 non-null   object
#  1   state                          4543 non-null   object
#  2   customer_lifetime_value        4543 non-null   float64
#  3   response                       4543 non-null   object
#  4   coverage                       4543 non-null   object
#  5   education                      4543 non-null   object
#  6   effective_to_date              4543 non-null   datetime64[ns]
#  7   employment_status              4543 non-null   object
#  8   gender                         4543 non-null   object
#  9   income                         4543 non-null   int64
#  10  location_code                  4543 non-null   object
#  11  marital_status                 4543 non-null   object
# ...

# %%
#X-y split.

X = numerical.drop(['total_claim_amount'], axis=1)
y = numerical['total_claim_amount']

# %%
#Normalize

from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
x_num = X.select_dtypes(include = np.number)
x_cat = X.select_dtypes(include = np.object)

# %%
#Normalize


transformer = Normalizer()
transformer.fit(x_num)
x_normalized = transformer.transform(x_num)
pd.DataFrame(x_normalized)
x_normalized.shape
# Out:
# (4543, 7)

# %%
sns.distplot(x_normalized.T[0])
# Out:
# <AxesSubplot:ylabel='Density'>
